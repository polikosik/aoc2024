# %%
import pandas as pd
import os

absolute_path = os.getcwd()
relative_path = 'input.txt'
full_path = os.path.join(absolute_path, relative_path)

df = pd.read_csv(full_path, sep='   ', header=None,names=['A','B'])

df
# Out:
# C:\Users\Pawel\AppData\Local\Temp\ipykernel_1924\3554380442.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(full_path, sep='   ', header=None,names=['A','B'])
#          A      B
# 0    47078  87818
# 1    99261  15906
# 2    44723  23473
# 3    87598  26876
# 4    82172  24873
# ..     ...    ...
# 995  81820  84843
# 996  17509  85554
# 997  47369  11182
# 998  34359  84179
# 999  45592  15347
#
# [1000 rows x 2 columns]

# %%
slownik = {}

for value in df['A']:
    count = (df['B'] == value).sum()  
    slownik[value] = int(count)

slownik
# Out:
# {47078: 0,
#  99261: 0,
#  44723: 0,
#  87598: 0,
#  82172: 0,
#  92690: 0,
#  46104: 0,
#  17300: 0,
#  67643: 0,
#  81513: 0,
#  29550: 0,
#  41437: 0,
#  50927: 0,
#  59085: 0,
#  70043: 0,
#  60337: 0,
#  96311: 0,
#  84634: 0,
#  52702: 19,
#  24182: 0,
#  73443: 0,
#  72022: 0,
#  62248: 0,
#  41418: 0,
#  92718: 10,
#  95875: 0,
#  84233: 0,
#  49551: 0,
#  77689: 20,
#  21344: 0,
#  45466: 0,
#  13812: 0,
#  57869: 0,
#  78200: 0,
#  44981: 0,
#  35500: 0,
#  27169: 0,
#  48956: 0,
#  44999: 19,
#  87641: 0,
#  97594: 0,
#  26029: 0,
#  56082: 0,
#  37413: 0,
#  16310: 0,
#  36134: 0,
#  40339: 0,
#  87392: 0,
#  85426: 0,
#  50693: 0,
#  72999: 0,
#  37541: 0,
#  33772: 0,
#  94796: 0,
#  90202: 0,
#  38330: 0,
#  39478: 0,
#  76029: 0,
#  65969: 0,
#  63748: 0,
#  45284: 0,
#  80539: 5,
#  39367: 0,
#  81324: 0,
#  39057: 0,
#  78121: 0,
#  66791: 0,
#  15405: 0,
#  26614: 0,
#  74178: 0,
#  58206: 0,
#  58390: 0,
#  59886: 0,
#  58977: 0,
#  44549: 0,
#  43761: 0,
# ...

# %%
roll = 0

for key in slownik:
    roll = roll + slownik[key] * int(key) 

roll
# Out:
# 22545250
